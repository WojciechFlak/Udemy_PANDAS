# %%
import datetime
import pandas as pd
import matplotlib as mpl
# %matplotlib inline

nasa = pd.read_csv("../Labs files//course-files/nasa_facebook_statuses.csv",
                    usecols=["status_published","num_reactions", "num_comments",
                             "num_shares","num_likes"])

nasa["status_published"] = pd.to_datetime(nasa["status_published"])

filter =(nasa['status_published'] >= '2016-5-1') & (nasa['status_published'] < '2016-6-1')
nasa = nasa[filter]

nasa['day'] = nasa.apply(lambda row: row["status_published"].day,axis=1)

nasa_by_day = nasa.groupby(by='day').sum()
nasa_by_day.head()
# Out:
# /var/folders/rz/24qlfvg126sfp2zf4589lt9h0000gn/T/ipykernel_47271/3910441305.py:17: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   nasa_by_day = nasa.groupby(by='day').sum()
#      num_reactions  num_comments  num_shares  num_likes
# day
# 1            62629           727        4403      60243
# 2           188255          2328       23897     177989
# 3            53700           770       10858      50264
# 4           140098          1776       23360     133302
# 5            93146          1070        7627      89657

# %%
nasa_by_day.plot()
# Out:
# <AxesSubplot: xlabel='day'>

# %%
nasa_by_day['num_shares']. plot()
# Out:
# <AxesSubplot: xlabel='day'>

# %%
nasa_by_day.plot(y='num_shares')
# Out:
# <AxesSubplot: xlabel='day'>

# %%
nasa_by_day.plot(y=['num_shares','num_comments'])
# Out:
# <AxesSubplot: xlabel='day'>

# %%
nasa_by_day[['num_shares','num_comments']].plot()
# Out:
# <AxesSubplot: xlabel='day'>

# %%
nasa_by_day.plot(figsize=(15,5))
# Out:
# <AxesSubplot: xlabel='day'>

# %%
nasa_by_day.plot(figsize=(15,5),title="NASA Facebook activity")
# Out:
# <AxesSubplot: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day.plot(figsize=(15,15),title="NASA Facebook activity",subplots=True)
# Out:
# array([<AxesSubplot: xlabel='day'>, <AxesSubplot: xlabel='day'>,
#        <AxesSubplot: xlabel='day'>, <AxesSubplot: xlabel='day'>],
#       dtype=object)

# %%
nasa_by_day.plot(figsize=(15,15),title="NASA Facebook activity",logy=True)
# Out:
# <AxesSubplot: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day.plot(figsize=(15,15),title="NASA Facebook activity",xticks=range(1,32),rot=45)
# Out:
# <AxesSubplot: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day[:10].plot(title="NASA Facebook activity",xticks=range(1,31),rot=45,
                     table=True)
# Out:
# <AxesSubplot: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day[:10].plot(table=True,xlabel='',xticks=([]))
# Out:
# <AxesSubplot: >

# %%
nasa_by_day.plot(title='NASA Facebook activity', figsize=(15,5),color = ['r','g','b','k'])
# Out:
# <AxesSubplot: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
nasa_by_day.plot(title='NASA Facebook activity', figsize=(15,5),colormap='spring')
# Out:
# <AxesSubplot: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
mpl.style.use('fivethirtyeight')
nasa_by_day.plot(title='NASA Facebook activity', figsize=(15,5),colormap='autumn')
# Out:
# <AxesSubplot: title={'center': 'NASA Facebook activity'}, xlabel='day'>

# %%
mpl.style.use('dark_background')
nasa_by_day.plot(title='NASA Facebook activity', figsize=(15,5),colormap='autumn')
# Out:
# <AxesSubplot: title={'center': 'NASA Facebook activity'}, xlabel='day'>
